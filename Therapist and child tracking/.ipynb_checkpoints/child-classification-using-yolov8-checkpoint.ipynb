# %% [markdown]
# # Ignoring warnings using warning module

# %%
import warnings as warn
warn.filterwarnings('ignore')

# %% [markdown]
# # Installing Ultralytics library

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.5/719.5 kB 25.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Installing YoloV8

# %%
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5518.9/8062.4 GB disk)

# %% [markdown]
# # Downloading dataset using roboflow

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="nfBDjbhZIESZICEXpniP")
project = rf.workspace("vallabha-group-of-companies").project("child-adult-dataset")
version = project.version(1)
dataset = version.download("folder")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
import os 
os.rename('/kaggle/working/CHILD-ADULT-DATASET-1/valid','/kaggle/working/CHILD-ADULT-DATASET-1/val')

# %% [markdown]
# # Getting started with model training

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data='/kaggle/working/CHILD-ADULT-DATASET-1' epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %% [markdown]
# # Visualizing the confusion matrix to check model performance

# %%
Image('/kaggle/working/runs/classify/train3/confusion_matrix_normalized.png',width=600)

# %% [markdown]
# # Visualizing the results of model training

# %%
Image('/kaggle/working/runs/classify/train3/results.png',width=600)

# %% [markdown]
# # Getting started with model validation

# %%
# !yolo task=classify mode=val model='/kaggle/working/runs/classify/train3/weights/best.pt' data='/kaggle/working/CHILD-ADULT-DATASET-1'
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# train: /kaggle/working/CHILD-ADULT-DATASET-1/train... found 557 images in 2 classes ✅
# val: /kaggle/working/CHILD-ADULT-DATASET-1/val... found 158 images in 2 classes ✅
# test: /kaggle/working/CHILD-ADULT-DATASET-1/test... found 82 images in 2 classes ✅
# val: Scanning /kaggle/working/CHILD-ADULT-DATASET-1/val... 158 images, 0 corrupt
#                classes   top1_acc   top5_acc: 100%|██████████| 10/10 [00:02<00:0
#                    all      0.892          1
# Speed: 5.0ms preprocess, 5.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# # viewing validation results

# %%
Image('/kaggle/working/runs/classify/val/val_batch0_pred.jpg',width=600)

# %%
Image('/kaggle/working/runs/classify/val/val_batch1_pred.jpg',width=600)

# %%
Image('/kaggle/working/runs/classify/val/val_batch2_pred.jpg',width=600)

# %% [markdown]
# # Getting started with model prediction

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train3/weights/best.pt' conf=0.25 source="/kaggle/working/CHILD-ADULT-DATASET-1/test/adults/52_jpg.rf.33d693edb602fdd6769ee5cd569a11c7.jpg"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /kaggle/working/CHILD-ADULT-DATASET-1/test/adults/52_jpg.rf.33d693edb602fdd6769ee5cd569a11c7.jpg: 640x640 adults 1.00, children 0.00, 3.8ms
# Speed: 17.0ms preprocess, 3.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('/kaggle/working/runs/classify/predict2/52_jpg.rf.33d693edb602fdd6769ee5cd569a11c7.jpg',width=600)

# %%
# !yolo task=classify mode=predict model= '/kaggle/working/runs/classify/train3/weights/best.pt' conf=0.25 source="/kaggle/working/CHILD-ADULT-DATASET-1/test/children/350_jpg.rf.011a7f6aeeea7684b708157a33de1e87.jpg"
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/1 /kaggle/working/CHILD-ADULT-DATASET-1/test/children/350_jpg.rf.011a7f6aeeea7684b708157a33de1e87.jpg: 640x640 children 0.95, adults 0.05, 4.1ms
# Speed: 19.5ms preprocess, 4.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('/kaggle/working/runs/classify/predict3/350_jpg.rf.011a7f6aeeea7684b708157a33de1e87.jpg',width=600)
